# %%
import pandas as pd
import geopandas as gpd

# %%
census = gpd.read_file('data/UMC.csv')
#Census data

# %%
TOC = gpd.read_file('data/UMT.csv')
#TOC entries

# %%
census.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   GEOID                    2346 non-null   object
#  1   MedianHouseholdIncome16  2346 non-null   object
#  2   PerOO16                  2346 non-null   object
#  3   Housing Units:           2346 non-null   object
#  4   Housing Units: 1 Unit    2346 non-null   object
#  5   PerSingFam16             2346 non-null   object
#  6   Median HomeValue16       2346 non-null   object
#  7   MedianGrossRent16        2346 non-null   object
#  8   geometry                 0 non-null      geometry
# dtypes: geometry(1), object(8)
# memory usage: 165.1+ KB

# %%
TOC.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fid         354 non-null    object
#  1   AIN         354 non-null    object
#  2   SitusAddre  354 non-null    object
#  3   GEOID10     354 non-null    object
#  4   geometry    0 non-null      geometry
# dtypes: geometry(1), object(4)
# memory usage: 14.0+ KB

# %%
TOC1 = TOC.rename(columns={'GEOID10' : 'GEOID'})

# %%
TOC1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fid         354 non-null    object
#  1   AIN         354 non-null    object
#  2   SitusAddre  354 non-null    object
#  3   GEOID       354 non-null    object
#  4   geometry    0 non-null      geometry
# dtypes: geometry(1), object(4)
# memory usage: 14.0+ KB

# %%
merged = TOC1.merge(census,on='GEOID')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354 entries, 0 to 353
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   fid                      354 non-null    object
#  1   AIN                      354 non-null    object
#  2   SitusAddre               354 non-null    object
#  3   GEOID                    354 non-null    object
#  4   geometry_x               0 non-null      geometry
#  5   MedianHouseholdIncome16  354 non-null    object
#  6   PerOO16                  354 non-null    object
#  7   Housing Units:           354 non-null    object
#  8   Housing Units: 1 Unit    354 non-null    object
#  9   PerSingFam16             354 non-null    object
#  10  Median HomeValue16       354 non-null    object
#  11  MedianGrossRent16        354 non-null    object
#  12  geometry_y               0 non-null      geometry
# dtypes: geometry(2), object(11)
# memory usage: 38.7+ KB

# %%
merged.head()
# Out:
#   fid         AIN          SitusAddre       GEOID geometry_x  \
# 0   1  6048004030  9543 S COMPTON AVE  6037242300       None
# 1   2  6048022066  9220 S COMPTON AVE  6037242300       None
# 2   3  6048004025  9515 S COMPTON AVE  6037242300       None
# 3   4  6046019930      2062 E 99TH PL  6037242100       None
# 4   5  6022022011  410 E FLORENCE AVE  6037239501       None
#
#   MedianHouseholdIncome16      PerOO16 Housing Units: Housing Units: 1 Unit  \
# 0                   31202  35.23012552           1242                   774
# 1                   31202  35.23012552           1242                   774
# 2                   31202  35.23012552           1242                   774
# 3                   14728            0            759                   141
# 4                   31000  35.18930958            937                   721
#
#   PerSingFam16 Median HomeValue16 MedianGrossRent16 geometry_y
# 0  62.31884058             222900              1025       None
# ...

# %%
merged.sample(10)
#All entries confirmed against Social Explorer
# Out:
#      fid         AIN             SitusAddre       GEOID geometry_x  \
# 54    52  5080012006       3057 W PICO BLVD  6037213202       None
# 168  170  4314022036     3308 S MENTONE AVE  6037269904       None
# 251  256  4236021021       12800 W ZANJA ST  6037272202       None
# 143  191  5534019029   5820 W LA MIRADA AVE  6037190902       None
# 115  108  4261019006      1775 S BELOIT AVE  6037267300       None
# 208  209  6020009031          950 W 76TH ST  6037237720       None
# 338  333  2353013004      11246 W OTSEGO ST  6037125401       None
# 137  137  5542003016  4531 W HOLLYWOOD BLVD  6037195300       None
# 24    24  5156003004        252 N HOOVER ST  6037208610       None
# 123  113  4267036009   1223 S WELLESLEY AVE  6037267402       None
#
#     MedianHouseholdIncome16      PerOO16 Housing Units: Housing Units: 1 Unit  \
# 54                    33800  16.28264209           1385                   378
# ...

# %%
merged = merged.drop(columns=['geometry_x','geometry_y'])

# %%
merged.head()
# Out:
#   fid         AIN          SitusAddre       GEOID MedianHouseholdIncome16  \
# 0   1  6048004030  9543 S COMPTON AVE  6037242300                   31202
# 1   2  6048022066  9220 S COMPTON AVE  6037242300                   31202
# 2   3  6048004025  9515 S COMPTON AVE  6037242300                   31202
# 3   4  6046019930      2062 E 99TH PL  6037242100                   14728
# 4   5  6022022011  410 E FLORENCE AVE  6037239501                   31000
#
#        PerOO16 Housing Units: Housing Units: 1 Unit PerSingFam16  \
# 0  35.23012552           1242                   774  62.31884058
# 1  35.23012552           1242                   774  62.31884058
# 2  35.23012552           1242                   774  62.31884058
# 3            0            759                   141   18.5770751
# 4  35.18930958            937                   721  76.94770544
#
#   Median HomeValue16 MedianGrossRent16
# 0             222900              1025
# 1             222900              1025
# ...

# %%
TOC2 = gpd.read_file('TOC_11_2021/data/TC.csv')

# %%
TOC2.shape
# Out:
# (357, 31)

# %%
TOC2.head(10)
# Out:
#           AIN    TOC Status confirmTOC notes include               Address  \
# 0  2138003020    Non-TOC BR                        1     7043 N JORDAN AVE
# 1  2138022010  Non-TOC Disc                        1    21121 W VANOWEN ST
# 2  2148027005  Non-TOC Disc                        1    20944 W VANOWEN ST
# 3  2206011022    Non-TOC BR                        1    15755 W SATICOY ST
# 4  2210031012  Non-TOC Disc                        1  7639 N VAN NUYS BLVD
# 5  2220005003    Non-TOC BR                        1   14954 W SHERMAN WAY
# 6  2221021005    Non-TOC BR                        1  14912 W WYANDOTTE ST
# 7  2224004006  Non-TOC Disc                        1   16030 W SHERMAN WAY
# 8  2237001017  Non-TOC Disc                        1  6600 N VAN NUYS BLVD
# 9  2239006030  Non-TOC Disc                        1  13724 W VICTORY BLVD
#
#                  cp_casenum full_approvetime minus_holddays zc_floorarea  ...  \
# ...

# %%
TOC2.tail(20)
# Out:
#             AIN    TOC Status confirmTOC  \
# 337  6032024022        TOC BR          1
# 338  6038010026  Non-TOC Disc          0
# 339  6038010902        TOC BR          1
# 340  6046019920  Non-TOC Disc
# 341  6046019927    Non-TOC BR
# 342  6046019930  Non-TOC Disc
# 343  6046021918    Non-TOC BR
# 344  6048004025        TOC BR          1
# 345  6048004030    Non-TOC BR
# 346  6048022066    Non-TOC BR
# 347  6070016007  Non-TOC Disc
# 348  6088009036  Non-TOC Disc
# 349  7418004008    Non-TOC BR
# 350  7418004009    Non-TOC BR
# 351  7455012022        TOC BR          1
# 352  4217018032      TOC DISC          1
# 353
# 354
# 355
# 356
#
#                                                  notes include  \
# 337                                                          1
# 338  Remove this one -- permit data is strange, and...       0
# 339                                                          1
# 340                                                          1
# ...

# %%
TOC2.drop(TOC2.tail(4).index,inplace=True)

# %%
TOC2.tail(10)
# Out:
#             AIN    TOC Status confirmTOC notes include              Address  \
# 343  6046021918    Non-TOC BR                        1  2300 E CENTURY BLVD
# 344  6048004025        TOC BR          1             1   9515 S COMPTON AVE
# 345  6048004030    Non-TOC BR                        1   9543 S COMPTON AVE
# 346  6048022066    Non-TOC BR                        1   9220 S COMPTON AVE
# 347  6070016007  Non-TOC Disc                        1  11408 S CENTRAL AVE
# 348  6088009036  Non-TOC Disc                        1  11516 S VERMONT AVE
# 349  7418004008    Non-TOC BR                        1           221 W E ST
# 350  7418004009    Non-TOC BR                        1     505 N MARINE AVE
# 351  7455012022        TOC BR          1             1         336 W 7TH ST
# 352  4217018032      TOC DISC          1             1   846 S MARIPOSA AVE
#
#                     cp_casenum full_approvetime minus_holddays zc_floorarea  \
# ...

# %%
TOC2 = TOC2.drop(columns=['PerSingleFam','% Owner-Occupied','Median Household Income (Lagged 2012-2016)2','Median Home Value (Lagged 2012-2016)3','Median Gross Rent (Lagged 2012-2016)4','AIN JOINCHECK','Address JOINCHECK'])

# %%
TOC2.head(10)
# Out:
#           AIN    TOC Status confirmTOC notes include               Address  \
# 0  2138003020    Non-TOC BR                        1     7043 N JORDAN AVE
# 1  2138022010  Non-TOC Disc                        1    21121 W VANOWEN ST
# 2  2148027005  Non-TOC Disc                        1    20944 W VANOWEN ST
# 3  2206011022    Non-TOC BR                        1    15755 W SATICOY ST
# 4  2210031012  Non-TOC Disc                        1  7639 N VAN NUYS BLVD
# 5  2220005003    Non-TOC BR                        1   14954 W SHERMAN WAY
# 6  2221021005    Non-TOC BR                        1  14912 W WYANDOTTE ST
# 7  2224004006  Non-TOC Disc                        1   16030 W SHERMAN WAY
# 8  2237001017  Non-TOC Disc                        1  6600 N VAN NUYS BLVD
# 9  2239006030  Non-TOC Disc                        1  13724 W VICTORY BLVD
#
#                  cp_casenum full_approvetime minus_holddays zc_floorarea  ...  \
# ...

# %%
TOC2 = TOC2.drop(columns=['geometry'])
TOC2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 353 entries, 0 to 352
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AIN               353 non-null    object
#  1   TOC Status        353 non-null    object
#  2   confirmTOC        353 non-null    object
#  3   notes             353 non-null    object
#  4   include           353 non-null    object
#  5   Address           353 non-null    object
#  6   cp_casenum        353 non-null    object
#  7   full_approvetime  353 non-null    object
#  8   minus_holddays    353 non-null    object
#  9   zc_floorarea      353 non-null    object
#  10  total_units       353 non-null    object
#  11  aff_units         353 non-null    object
#  12  mr_units          353 non-null    object
#  13  pct_aff           353 non-null    object
#  14  Council District  353 non-null    object
#  15  TOC Dist          353 non-null    object
# ...

# %%
TOC_Census_Fix_11_8_2021 = TOC2.merge(merged,on='AIN')

# %%
TOC_Census_Fix_11_8_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 351
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIN                      352 non-null    object
#  1   TOC Status               352 non-null    object
#  2   confirmTOC               352 non-null    object
#  3   notes                    352 non-null    object
#  4   include                  352 non-null    object
#  5   Address                  352 non-null    object
#  6   cp_casenum               352 non-null    object
#  7   full_approvetime         352 non-null    object
#  8   minus_holddays           352 non-null    object
#  9   zc_floorarea             352 non-null    object
#  10  total_units              352 non-null    object
#  11  aff_units                352 non-null    object
#  12  mr_units                 352 non-null    object
#  13  pct_aff                  352 non-null    object
# ...

# %%
TOC_Census_Fix_11_8_2021.head(10)
# Out:
#           AIN    TOC Status confirmTOC notes include               Address  \
# 0  2138003020    Non-TOC BR                        1     7043 N JORDAN AVE
# 1  2138022010  Non-TOC Disc                        1    21121 W VANOWEN ST
# 2  2148027005  Non-TOC Disc                        1    20944 W VANOWEN ST
# 3  2206011022    Non-TOC BR                        1    15755 W SATICOY ST
# 4  2210031012  Non-TOC Disc                        1  7639 N VAN NUYS BLVD
# 5  2220005003    Non-TOC BR                        1   14954 W SHERMAN WAY
# 6  2221021005    Non-TOC BR                        1  14912 W WYANDOTTE ST
# 7  2224004006  Non-TOC Disc                        1   16030 W SHERMAN WAY
# 8  2237001017  Non-TOC Disc                        1  6600 N VAN NUYS BLVD
# 9  2239006030  Non-TOC Disc                        1  13724 W VICTORY BLVD
#
#                  cp_casenum full_approvetime minus_holddays zc_floorarea  ...  \
# ...

# %%
TOC_Census_Fix_11_8_2021 = TOC_Census_Fix_11_8_2021.drop(columns=['SitusAddre','fid','Housing Units:','Housing Units: 1 Unit'])
TOC_Census_Fix_11_8_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 351
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIN                      352 non-null    object
#  1   TOC Status               352 non-null    object
#  2   confirmTOC               352 non-null    object
#  3   notes                    352 non-null    object
#  4   include                  352 non-null    object
#  5   Address                  352 non-null    object
#  6   cp_casenum               352 non-null    object
#  7   full_approvetime         352 non-null    object
#  8   minus_holddays           352 non-null    object
#  9   zc_floorarea             352 non-null    object
#  10  total_units              352 non-null    object
#  11  aff_units                352 non-null    object
#  12  mr_units                 352 non-null    object
#  13  pct_aff                  352 non-null    object
# ...

# %%
TOC_Census_Fix_11_8_2021.sample(5)
# Out:
#             AIN    TOC Status confirmTOC notes include                Address  \
# 334  6022022011      TOC DISC          1             1     410 E FLORENCE AVE
# 315  5542003016  Non-TOC Disc                        1  4531 W HOLLYWOOD BLVD
# 291  5522019003  Non-TOC Disc                        1     4749 W ELMWOOD AVE
# 280  5520024009  Non-TOC Disc                        1     338 N MARIPOSA AVE
# 14   2241017010        TOC BR          1             1      14848 W DELANO ST
#
#                 cp_casenum full_approvetime minus_holddays zc_floorarea  ...  \
# 334      DIR-2017-4059-TOC              465            406        42835  ...
# 315  DIR-2014-2578-SPP-SPR             1997           1743       229960  ...
# 291       CPC-2017-2121-DB              714            714        13410  ...
# 280       DIR-2014-4909-DB             1449           1171        16100  ...
# 14                                      330            330     11338.26  ...
#
# ...

# %%
TOC_Census_Fix_11_8_2021.to_csv(r'TOC_11_2021/output/TOC_Census_Fix_11_8_2021.csv')
