# %%
import pandas as pd
import geopandas as gpd

# %%
base = gpd.read_file('data/TOC_base.csv')

# %%
dates = gpd.read_file('data/TOC_dates.csv')

# %%
base.head(5)
# Out:
#           AIN    TOC Status confirmTOC notes include               Address  \
# 0  2138003020    Non-TOC BR                        1     7043 N JORDAN AVE
# 1  2138022010  Non-TOC Disc                        1    21121 W VANOWEN ST
# 2  2148027005  Non-TOC Disc                        1    20944 W VANOWEN ST
# 3  2206011022    Non-TOC BR                        1    15755 W SATICOY ST
# 4  2210031012  Non-TOC Disc                        1  7639 N VAN NUYS BLVD
#
#           cp_casenum full_approvetime minus_holddays zc_floorarea  ...  \
# 0                                 363            363        42095  ...
# 1  DIR-2016-4563-SPP              749            749      97611.8  ...
# 2   DIR-2016-3485-AC              540            540        46360  ...
# 3                                 497            497        33532  ...
# 4   DIR-2016-2920-DB              659            659        31359  ...
#
#    LV 2015 SPA DUMMY REDEV DUMMY       GEOID MedianHouseholdIncome16  \
# ...

# %%
base.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIN                      352 non-null    object
#  1   TOC Status               352 non-null    object
#  2   confirmTOC               352 non-null    object
#  3   notes                    352 non-null    object
#  4   include                  352 non-null    object
#  5   Address                  352 non-null    object
#  6   cp_casenum               352 non-null    object
#  7   full_approvetime         352 non-null    object
#  8   minus_holddays           352 non-null    object
#  9   zc_floorarea             352 non-null    object
#  10  total_units              352 non-null    object
#  11  aff_units                352 non-null    object
#  12  mr_units                 352 non-null    object
#  13  pct_aff                  352 non-null    object
# ...

# %%
dates.head(5)
# Out:
#           AIN TOC Dummy DISC Dummy  cp_filing  cp_complet cp_approva  \
# 0  2317017002         1          1  3/16/2018   4/19/2018  7/23/2018
# 1  2338028017         1          1  2/12/2018   5/15/2018  7/30/2018
# 2  2353013004         1          1   3/8/2018  11/28/2018  2/11/2019
# 3  4006020010         1          1  2/26/2019    5/1/2019  7/12/2019
# 4  4103022009         1          1  2/12/2019   4/23/2019  5/15/2019
#
#           permit_num  ladbs_subm  ladbs_perm ladbs_appr geometry
# 0  17010-20000-02985  2017-08-04  2019-09-19        776     None
# 1  16010-20000-06202  2016-12-27  2018-12-18        721     None
# 2  16010-20000-06204  2016-12-27  2019-08-01        947     None
# 3  19010-20000-02725   6/25/2019   3/10/2020        259     None
# 4  18010-20000-04140   8/23/2018   2/21/2020        547     None

# %%
dates.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AIN         353 non-null    object
#  1   TOC Dummy   353 non-null    object
#  2   DISC Dummy  353 non-null    object
#  3   cp_filing   353 non-null    object
#  4   cp_complet  353 non-null    object
#  5   cp_approva  353 non-null    object
#  6   permit_num  353 non-null    object
#  7   ladbs_subm  353 non-null    object
#  8   ladbs_perm  353 non-null    object
#  9   ladbs_appr  353 non-null    object
#  10  geometry    0 non-null      geometry
# dtypes: geometry(1), object(10)
# memory usage: 30.5+ KB

# %%
TOC3 = base.merge(dates,on='AIN')

# %%
TOC3.head(5)
# Out:
#           AIN    TOC Status confirmTOC notes include               Address  \
# 0  2138003020    Non-TOC BR                        1     7043 N JORDAN AVE
# 1  2138022010  Non-TOC Disc                        1    21121 W VANOWEN ST
# 2  2148027005  Non-TOC Disc                        1    20944 W VANOWEN ST
# 3  2206011022    Non-TOC BR                        1    15755 W SATICOY ST
# 4  2210031012  Non-TOC Disc                        1  7639 N VAN NUYS BLVD
#
#           cp_casenum full_approvetime minus_holddays zc_floorarea  ...  \
# 0                                 363            363        42095  ...
# 1  DIR-2016-4563-SPP              749            749      97611.8  ...
# 2   DIR-2016-3485-AC              540            540        46360  ...
# 3                                 497            497        33532  ...
# 4   DIR-2016-2920-DB              659            659        31359  ...
#
#   TOC Dummy DISC Dummy   cp_filing  cp_complet  cp_approva         permit_num  \
# ...

# %%
TOC3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 351
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIN                      352 non-null    object
#  1   TOC Status               352 non-null    object
#  2   confirmTOC               352 non-null    object
#  3   notes                    352 non-null    object
#  4   include                  352 non-null    object
#  5   Address                  352 non-null    object
#  6   cp_casenum               352 non-null    object
#  7   full_approvetime         352 non-null    object
#  8   minus_holddays           352 non-null    object
#  9   zc_floorarea             352 non-null    object
#  10  total_units              352 non-null    object
#  11  aff_units                352 non-null    object
#  12  mr_units                 352 non-null    object
#  13  pct_aff                  352 non-null    object
# ...

# %%
TOC3 = TOC3.drop(columns=['geometry_x','geometry_y','ladbs_appr'])

# %%
TOC3.sample(5)
# Out:
#             AIN    TOC Status confirmTOC notes include                Address  \
# 232  5147029048  Non-TOC Disc                        1     660 S STANFORD AVE
# 294  5523022012  Non-TOC Disc                        1     647 N BEACHWOOD DR
# 149  4323013044    Non-TOC BR                        1  1835 S GREENFIELD AVE
# 347  6070016007  Non-TOC Disc                        1    11408 S CENTRAL AVE
# 328  6011008027        TOC BR          1             1     325 E FLORENCE AVE
#
#                         cp_casenum full_approvetime minus_holddays  \
# 232  CPC-2017-849-GPAJ-VZCJ-HD-SPR             1019           1019
# 294               CPC-2016-4316-DB              733            733
# 149                                             544            544
# 347      DIR-2019-3117-SPR-PSH-SIP              297            250
# 328                                             200            200
#
#     zc_floorarea  ... Median HomeValue16 MedianGrossRent16 TOC Dummy  \
# ...

# %%
#TOC3.to_csv(r'output/TOC_11_9_2021.csv')

# %%
TOC3 = TOC3.drop(columns=['ProximityCBD'])

# %%
TOC3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 351
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIN                      352 non-null    object
#  1   TOC Status               352 non-null    object
#  2   confirmTOC               352 non-null    object
#  3   notes                    352 non-null    object
#  4   include                  352 non-null    object
#  5   Address                  352 non-null    object
#  6   cp_casenum               352 non-null    object
#  7   full_approvetime         352 non-null    object
#  8   minus_holddays           352 non-null    object
#  9   zc_floorarea             352 non-null    object
#  10  total_units              352 non-null    object
#  11  aff_units                352 non-null    object
#  12  mr_units                 352 non-null    object
#  13  pct_aff                  352 non-null    object
# ...

# %%
CBD = gpd.read_file('data/TOC_CBD.csv')

# %%
CBD.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AIN       354 non-null    object
#  1   HubDist   354 non-null    object
#  2   geometry  0 non-null      geometry
# dtypes: geometry(1), object(2)
# memory usage: 8.4+ KB

# %%
CBD.head(5)
# Out:
#           AIN      HubDist geometry
# 0  6048004030  6.826117105     None
# 1  6048022066  6.598419662     None
# 2  6048004025  6.809842121     None
# 3  6046019930  7.054173881     None
# 4  6022022011  5.147235524     None

# %%
CBD = CBD.rename(columns={'HubDist': 'CBDdist'})

# %%
CBD.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AIN       354 non-null    object
#  1   CBDdist   354 non-null    object
#  2   geometry  0 non-null      geometry
# dtypes: geometry(1), object(2)
# memory usage: 8.4+ KB

# %%
CBD['CBDdist'] = CBD['CBDdist'].astype(float)

# %%
CBD.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AIN       354 non-null    object
#  1   CBDdist   354 non-null    float64
#  2   geometry  0 non-null      geometry
# dtypes: float64(1), geometry(1), object(1)
# memory usage: 8.4+ KB

# %%
TOC4 = base.merge(CBD,on='AIN')

# %%
TOC4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 351
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIN                      352 non-null    object
#  1   TOC Status               352 non-null    object
#  2   confirmTOC               352 non-null    object
#  3   notes                    352 non-null    object
#  4   include                  352 non-null    object
#  5   Address                  352 non-null    object
#  6   cp_casenum               352 non-null    object
#  7   full_approvetime         352 non-null    object
#  8   minus_holddays           352 non-null    object
#  9   zc_floorarea             352 non-null    object
#  10  total_units              352 non-null    object
#  11  aff_units                352 non-null    object
#  12  mr_units                 352 non-null    object
#  13  pct_aff                  352 non-null    object
# ...

# %%
pd.set_option('display.max_columns',None)
TOC4.sample(5)
# Out:
#             AIN    TOC Status confirmTOC  \
# 165  5016014002      TOC DISC          1
# 74   2530008901  Non-TOC Disc
# 242  5157020021      TOC DISC          1
# 182  5070017001        TOC BR          1
# 332  6018032001        TOC BR          1
#
#                                                  notes include  \
# 165                                                          1
# 74                                                           1
# 242                                                          1
# 182  changed to TOC BR -- started date for permit p...       1
# 332                                                          1
#
#                      Address                cp_casenum full_approvetime  \
# 165       4604 S WESTERN AVE        DIR-2018-5204-TOC               547
# 74   11800 W KAGEL CANYON ST  DIR-2018-2406-ACI-DB-WDI              621
# 242            226 N LAKE ST         DIR-2017-4561-TOC              407
# ...

# %%
TOC4 = TOC4.drop(columns=['geometry_x','geometry_y'])

# %%
TOC4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 351
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIN                      352 non-null    object
#  1   TOC Status               352 non-null    object
#  2   confirmTOC               352 non-null    object
#  3   notes                    352 non-null    object
#  4   include                  352 non-null    object
#  5   Address                  352 non-null    object
#  6   cp_casenum               352 non-null    object
#  7   full_approvetime         352 non-null    object
#  8   minus_holddays           352 non-null    object
#  9   zc_floorarea             352 non-null    object
#  10  total_units              352 non-null    object
#  11  aff_units                352 non-null    object
#  12  mr_units                 352 non-null    object
#  13  pct_aff                  352 non-null    object
# ...

# %%
TOC3.to_csv(r'output/TOC_11_9_2021.csv')
